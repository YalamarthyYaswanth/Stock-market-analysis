# %%
import pandas as pd
import datetime

# %%
df=pd.read_csv('MRF.NS.csv', index_col='Date',parse_dates=True)

# %%
df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-08-13  56601.300781  57390.898438  56011.101563  56736.800781
# 2019-08-14  56621.000000  57871.500000  56350.000000  57293.000000
# 2019-08-16  57300.000000  58300.000000  56501.398438  56823.601563
# 2019-08-19  57010.000000  57745.000000  57010.000000  57589.800781
# 2019-08-20  57502.000000  57857.000000  57228.898438  57548.898438
# ...                  ...           ...           ...           ...
# 2020-08-06  61500.000000  61850.000000  61100.000000  61345.800781
# 2020-08-07  61250.000000  63260.000000  61250.000000  62702.800781
# 2020-08-10  62798.000000  63550.000000  61700.000000  61863.000000
# 2020-08-11  62200.000000  62490.000000  61390.000000  61460.398438
# 2020-08-12  61640.000000  61899.851563  61350.000000  61634.750000
#
#                Adj Close   Volume
# Date
# 2019-08-13  56731.714844   7241.0
# 2019-08-14  57287.863281   8058.0
# 2019-08-16  56818.507813   5761.0
# ...

# %%
df.shape
# Out:
# (246, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 246 entries, 2019-08-13 to 2020-08-12
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       245 non-null    float64
#  1   High       245 non-null    float64
#  2   Low        245 non-null    float64
#  3   Close      245 non-null    float64
#  4   Adj Close  245 non-null    float64
#  5   Volume     245 non-null    float64
# dtypes: float64(6)
# memory usage: 13.5 KB

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
pd.set_option('display.max_rows',2468)

# %%
df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-08-13  56601.300781  57390.898438  56011.101563  56736.800781
# 2019-08-14  56621.000000  57871.500000  56350.000000  57293.000000
# 2019-08-16  57300.000000  58300.000000  56501.398438  56823.601563
# 2019-08-19  57010.000000  57745.000000  57010.000000  57589.800781
# 2019-08-20  57502.000000  57857.000000  57228.898438  57548.898438
# 2019-08-21  57501.000000  57857.000000  57200.000000  57737.000000
# 2019-08-22  57502.000000  57700.000000  56979.000000  57572.398438
# 2019-08-23  57600.000000  58400.000000  56521.101563  57859.500000
# 2019-08-26  58450.000000  59000.000000  57304.101563  58782.398438
# 2019-08-27  58780.000000  59499.000000  58650.601563  58871.500000
# 2019-08-28  58871.000000  59200.000000  57580.601563  57924.500000
# 2019-08-29  57950.000000  57988.000000  57188.101563  57545.601563
# 2019-08-30  57660.000000  58950.000000  57660.000000  58590.101563
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#             Open  High  Low  Close  Adj Close  Volume
# Date
# 2019-10-27   NaN   NaN  NaN    NaN        NaN     NaN

# %%
df1=df.dropna()

# %%
df1.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count    245.000000    245.000000    245.000000    245.000000    245.000000
# mean   62970.827758  63812.002105  62116.536878  62915.517857  62913.370329
# std     4144.610866   4015.726060   4193.214119   4103.943907   4103.757275
# min    50155.601563  55000.000000  49915.101563  51970.199219  51970.199219
# 25%    59499.898438  60460.101563  58500.000000  59461.500000  59456.167969
# 50%    63101.000000  63900.000000  62500.101563  63004.000000  63001.347656
# 75%    65749.000000  66300.000000  64720.101563  65335.898438  65335.898438
# max    73200.000000  73565.703125  71680.101563  73247.898438  73244.812500
#
#              Volume
# count    245.000000
# mean    9105.795918
# std     5744.182175
# min     2103.000000
# 25%     4973.000000
# 50%     7821.000000
# 75%    11453.000000
# max    39105.000000

# %%
df1["Open"].plot(figsize=(16,6))

# %% [markdown]
# # Min-Max scalar

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax =MinMaxScaler()
data1_df = minmax.fit_transform(df1)

# %%
df1_minmax=pd.DataFrame(data1_df,columns=['Open','High','Low','Close','Adj Close','Volume'])

# %%
df1_minmax
# Out:
#          Open      High       Low     Close  Adj Close    Volume
# 0    0.279708  0.128780  0.280083  0.224019   0.223812  0.138857
# 1    0.280563  0.154667  0.295654  0.250159   0.249954  0.160937
# 2    0.310028  0.177747  0.302610  0.228098   0.227892  0.098860
# 3    0.297443  0.147853  0.325977  0.264108   0.263903  0.052484
# 4    0.318793  0.153886  0.336035  0.262185   0.261981  0.030404
# 5    0.318750  0.153886  0.334707  0.271026   0.270822  0.049132
# 6    0.318793  0.145429  0.324553  0.263290   0.263085  0.081725
# 7    0.323046  0.183133  0.303515  0.276783   0.276579  0.101049
# 8    0.359931  0.215451  0.339490  0.320157   0.319956  0.079915
# 9    0.374251  0.242329  0.401355  0.324344   0.324143  0.055808
# 10   0.378200  0.226224  0.352194  0.279838   0.279634  0.035971
# 11   0.338234  0.160942  0.334160  0.262030   0.261826  0.022783
# 12   0.325650  0.212758  0.355842  0.311119   0.310918  0.076158
# ...

# %%
df1["Open"].plot(figsize=(16,6))

# %%
from scipy import stats

# %%
df1_zcore=stats.zscore(df1)

# %%
df1_zcore=(df1 - df1.mean())/df1.std(ddof=0)

# %%
df1_zcore
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2019-08-13 -1.539967 -1.602263 -1.459008 -1.508638  -1.509424 -0.325305
# 2019-08-14 -1.535205 -1.482338 -1.378022 -1.372833  -1.373625 -0.182783
# 2019-08-16 -1.371042 -1.375414 -1.341843 -1.487444  -1.488231 -0.583485
# 2019-08-19 -1.441156 -1.513904 -1.220303 -1.300364  -1.301158 -0.882833
# 2019-08-20 -1.322204 -1.485956 -1.167993 -1.310351  -1.311146 -1.025355
# 2019-08-21 -1.322446 -1.485956 -1.174899 -1.264422  -1.265219 -0.904465
# 2019-08-22 -1.322204 -1.525132 -1.227711 -1.304613  -1.305408 -0.694083
# 2019-08-23 -1.298511 -1.350461 -1.337134 -1.234512  -1.235310 -0.569355
# 2019-08-26 -1.093005 -1.200742 -1.150022 -1.009171  -1.009979 -0.705771
# 2019-08-27 -1.013221 -1.076227 -0.828250 -0.987415  -0.988224 -0.861377
# 2019-08-28 -0.991220 -1.150836 -1.083947 -1.218641  -1.219440 -0.989420
# 2019-08-29 -1.213891 -1.453268 -1.177742 -1.311156  -1.311951 -1.074549
# ...
